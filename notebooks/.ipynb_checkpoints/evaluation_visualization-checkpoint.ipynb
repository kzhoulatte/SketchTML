# %% [markdown]
# # Predict on test datasets:

# %%
# !python ./convert_batch_of_images.py --pngs_path {'../utils/screenshots_test/'} --output_folder {'./test/result'} --model_json_file {'./bin/model_json_voc23.json'} --model_weights_file {'./bin/weights_june20_008loss_011val.h5'}
# Out:
# Using TensorFlow backend.
# /Users/elsinore/anaconda/envs/insight/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 2018-06-21 21:36:00.564954: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
#
# Loaded model from disk
# Generating code for sample ID 0
# Saved generated HTML to ./test/result/0.html
# Generating code for sample ID 1
# Saved generated HTML to ./test/result/1.html
# Generating code for sample ID 10
# Saved generated HTML to ./test/result/10.html
# Generating code for sample ID 11
# Saved generated HTML to ./test/result/11.html
# Generating code for sample ID 12
# Saved generated HTML to ./test/result/12.html
# Generating code for sample ID 13
# Saved generated HTML to ./test/result/13.html
# ...

# %% [markdown]
# # Evaluate on BLEU score:

# %%
# !python evaluate_batch_guis.py --original_guis_filepath  {'../utils/gui_generated_test/'} --predicted_guis_filepath {'./test/result/'}
# Out:
# BLEU score for batch of GUIs: 0.8745891007983583
