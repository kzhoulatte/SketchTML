# %% [markdown]
# # Predict on test datasets:

# %%
# !python ../src/convert_batch_of_images.py --pngs_path {'../test/screenshots/'} --output_folder {'../test/result/'} --model_json_file {'../model/model.json'} --model_weights_file {'../model/weights.h5'}
# Out:
# Using TensorFlow backend.
# /Users/elsinore/anaconda/envs/insight/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 2018-06-28 01:40:47.534011: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
#
# Loaded model from disk
# Generating code for sample ID
# Saved generated HTML to ../test/result//.html
# Generating code for sample ID 0
# Saved generated HTML to ../test/result//0.html
# Generating code for sample ID 1
# Saved generated HTML to ../test/result//1.html
# Generating code for sample ID 10
# Saved generated HTML to ../test/result//10.html
# Generating code for sample ID 100
# Saved generated HTML to ../test/result//100.html
# Generating code for sample ID 101
# Saved generated HTML to ../test/result//101.html
# ...

# %% [markdown]
# # Evaluate on BLEU score:

# %%
# !python ../src/evaluate_batch_guis.py --original_guis_filepath  {'../test/gui_generated/'} --predicted_guis_filepath {'../test/result/'}
# Out:
# BLEU score for batch of GUIs: 0.8990184898144877
